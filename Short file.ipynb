# %%
from class_magnesium import *

# %%
m = Magnesium('short_list.csv')
print('Процент сайтов - %d' % (np.sum(m.y == 1)/m.y.shape[0]*100), str('%'))
# Out:
# Процент сайтов - 5 %

# %%
# без групп
Magnesium('short_list.csv', with_groups = False).compute(n_splits = 15, test_size = 0.3)
# Out:
# Feature reduction: 361 -> 129
# Average score: 0.947935204198
# 0.94793520419803778

# %%
# с группами
Magnesium('short_list.csv').compute(n_splits = 15, test_size = 0.3)
# Out:
# Feature reduction: 361 -> 130
# Average score: 0.945293597559
# 0.94529359755855291
