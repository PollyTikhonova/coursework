# %%
from class_magnesium import *

# %%
rfc7 = Magnesium("set_minresol_N_7.csv")
rfc7.compute(n_splits = 15, test_size = 0.3)
# Out:
# Feature reduction: 361 -> 130
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# Average score: 0.645500109588
# 0.64550010958758774

# %%
ys = rfc7.y[rfc7.y_data[1]]
print('Доля сайтов всего: ', np.sum(rfc7.y)/rfc7.y.shape[0])
print('Доля сайтов в последнем тесте: ',np.sum(ys)/ys.shape[0])
# Out:
# Доля сайтов всего:  0.361495679572
# Доля сайтов в последнем тесте:  0.30010742787

# %%
rfc3 = Magnesium("set_minresol_N_3.csv")
rfc3.compute(n_splits = 15, test_size = 0.3)
# Out:
# Feature reduction: 361 -> 128
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# Average score: 0.938319811159
# 0.93831981115911534

# %%
ys = rfc3.y[rfc3.y_data[1]]
print('Доля сайтов всего: ', np.sum(rfc3.y)/rfc3.y.shape[0])
print('Доля сайтов в последнем тесте: ',np.sum(ys)/ys.shape[0])
# Out:
# Доля сайтов всего:  0.0637680813482
# Доля сайтов в последнем тесте:  0.0531000613874

# %%
rfcm3 = Magnesium("set_maxmg_N_3.csv")
rfcm3.compute(n_splits = 15, test_size = 0.3)
# Out:
# Feature reduction: 361 -> 129
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# Average score: 0.920345005863
# 0.92034500586303813

# %%
ys = rfcm3.y[rfcm3.y_data[1]]
print('Доля сайтов всего: ', np.sum(rfcm3.y)/rfcm3.y.shape[0])
print('Доля сайтов в последнем тесте: ',np.sum(ys)/ys.shape[0])
# Out:
# Доля сайтов всего:  0.0825772298594
# Доля сайтов в последнем тесте:  0.0918240941468
