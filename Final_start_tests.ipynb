# %%
from class_magnesium import *

# %%
first = Magnesium("set_minresol_N_7.csv")
first.compute(n_splits = 15, test_size = 0.3,  reduce_features = False)
# Out:
# Average score: 0.652169274907
# 0.652169274907341

# %%
first = Magnesium("set_minresol_N_7.csv", with_groups = False)
first.compute(n_splits = 15, test_size = 0.3,  reduce_features = False)
# Out:
# Average score: 0.688575937197
# 0.68857593719749111

# %%
red = Magnesium("set_minresol_N_7.csv", with_groups = False)
red.compute(n_splits = 15, test_size = 0.3,  reduce_features = True)
# Out:
# Feature reduction: 361 -> 129
# Average score: 0.693522165201
# 0.69352216520136323

# %%
gr_red = Magnesium("set_minresol_N_7.csv", with_groups = True)
gr_red.compute(n_splits = 15, test_size = 0.3,  reduce_features = True)
# Out:
# Feature reduction: 361 -> 130
# Average score: 0.644910313951
# 0.64491031395087439

# %%
from sklearn.model_selection import cross_val_score
test = Magnesium("set_minresol_N_7.csv")
cr_gr = cross_val_score(test.model, test.x, test.y, test.groups, cv=15)
np.mean(cr_gr)
# Out:
# 0.61208544171289347

# %%
from sklearn.model_selection import cross_val_score
test = Magnesium("set_minresol_N_7.csv")
cr = cross_val_score(test.model, test.x, test.y, cv=15)
np.mean(cr)
# Out:
# 0.61098762103092707

# %%
from sklearn.model_selection import cross_val_score
test = Magnesium("set_minresol_N_7.csv")
test.choose_features(0,0)
cr_gr_red = cross_val_score(test.model, test.xt, test.y, test.groups, cv=15)
np.mean(cr_gr_red)
# Out:
# Feature reduction: 361 -> 130
# 0.57986300849329131

# %%
from sklearn.model_selection import cross_val_score
test = Magnesium("set_minresol_N_7.csv")
test.choose_features(0,0)
cr_red = cross_val_score(test.model, test.xt, test.y, cv=15)
np.mean(cr_red)
# Out:
# Feature reduction: 361 -> 130
# 0.57847860356827463
