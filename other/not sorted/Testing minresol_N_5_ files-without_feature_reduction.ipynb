# %%
from testing import *

# %%
fold = 'input files/'
file = os.listdir(fold.split('/')[0])

# %%
test(file, fold, False)
# Out:
# set_minresol_N_5.csv
# WITH GROUPS, RANDOMFOREST
#
# Number of sites:  6153
# Portion of sites:  0.230760576058
# Average score:  0.776920192019
# Last score:  0.777490249025
# Confusion matrix, without normalization
# [[20476    35]
#  [ 5898   255]]
# Normalized confusion matrix
# [[ 1.    0.  ]
#  [ 0.96  0.04]]
# WITHOUT GROUPS, RANDOMFOREST
#
# Number of sites:  6153
# Portion of sites:  0.230760576058
# Average score:  0.77701520152
# Last score:  0.77700270027
# Confusion matrix, without normalization
# [[20466    45]
#  [ 5901   252]]
# Normalized confusion matrix
# [[ 1.    0.  ]
#  [ 0.96  0.04]]
# set_minresol_N_5_b_b.csv
# WITH GROUPS, RANDOMFOREST
#
# Number of sites:  3991
# Portion of sites:  0.21432790935
# Average score:  0.789961154968
# Last score:  0.789914612534
# Confusion matrix, without normalization
# [[14606    24]
#  [ 3888   103]]
# Normalized confusion matrix
# [[ 1.    0.  ]
#  [ 0.97  0.03]]
# WITHOUT GROUPS, RANDOMFOREST
#
# Number of sites:  3991
# ...
