# %%
from class_magnesium import *

# %%
rfc1 = Magnesium("set_minresol_N_7.csv")
rfc1.compute(n_splits = 15, test_size = 0.1)
# Out:
# Feature reduction: 361 -> 130
# Average score: 0.644801105769
# 0.6448011057690527

# %%
rfc2 = Magnesium("set_minresol_N_7.csv")
rfc2.compute(n_splits = 15, test_size = 0.2)
# Out:
# Feature reduction: 361 -> 130
# Average score: 0.644784578226
# 0.64478457822646851

# %%
rfc3 = Magnesium("set_minresol_N_7.csv")
rfc3.compute(n_splits = 15, test_size = 0.3)
# Out:
# Feature reduction: 361 -> 130
# Average score: 0.644450693173
# 0.64445069317265813

# %%
rfc4 = Magnesium("set_minresol_N_7.csv")
rfc4.compute(n_splits = 15, test_size = 0.4)
# Out:
# Feature reduction: 361 -> 130
# Average score: 0.644328998105
# 0.64432899810539324

# %%
rfc5 = Magnesium("set_minresol_N_7.csv")
rfc5.compute(n_splits = 15, test_size = 0.5)
# Out:
# Feature reduction: 361 -> 130
# Average score: 0.644647323065
# 0.64464732306507555

# %%
rfc6 = Magnesium("set_minresol_N_7.csv")
rfc6.compute(n_splits = 15, test_size = 0.6)
# Out:
# Feature reduction: 361 -> 130
# Average score: 0.64489380415
# 0.64489380415009478

# %%
rfc7 = Magnesium("set_minresol_N_7.csv")
rfc7.compute(n_splits = 15, test_size = 0.7)
# Out:
# Feature reduction: 361 -> 130
# Average score: 0.644633221643
# 0.64463322164348291

# %%
rfc8 = Magnesium("set_minresol_N_7.csv")
rfc8.compute(n_splits = 15, test_size = 0.8)
# Out:
# Feature reduction: 361 -> 130
# Average score: 0.64530545018
# 0.64530545018047092
