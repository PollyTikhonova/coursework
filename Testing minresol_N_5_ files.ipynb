# %%
from testing import *

# %%
fold = 'input files/'
file = os.listdir(fold.split('/')[0])

# %%
test(file, fold)
# Out:
# set_minresol_N_5.csv
# WITH GROUPS, RANDOMFOREST
# Portion of sites =  0.23
# Feature reduction: 361 -> 130
#
# Average score: 0.775246297657
# WITHOUT GROUPS, RANDOMFOREST
# Feature reduction: 361 -> 130
#
# Average score: 0.779280428043
# set_minresol_N_5_b_b.csv
# WITH GROUPS, RANDOMFOREST
# Portion of sites =  0.21
# Feature reduction: 361 -> 129
#
# Average score: 0.793368200646
# WITHOUT GROUPS, RANDOMFOREST
# Feature reduction: 361 -> 129
#
# Average score: 0.789728442798
# set_minresol_N_5_b_m.csv
# WITH GROUPS, RANDOMFOREST
# Portion of sites =  0.2
# Feature reduction: 361 -> 128
#
# Average score: 0.799725080223
# WITHOUT GROUPS, RANDOMFOREST
# Feature reduction: 361 -> 128
#
# Average score: 0.799220713927
# set_minresol_N_5_m_b.csv
# WITH GROUPS, RANDOMFOREST
# Portion of sites =  0.34
# Feature reduction: 361 -> 128
#
# Average score: 0.606290855352
# WITHOUT GROUPS, RANDOMFOREST
# Feature reduction: 361 -> 129
#
# Average score: 0.775182616736
# ...
